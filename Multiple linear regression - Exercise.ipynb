# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('dataset/boston_housing.csv',usecols=['INDUS','RM','TAX','DIS','MEDV'])
df.head()
# Out:
#    INDUS     RM     DIS  TAX  MEDV
# 0   2.31  6.575  4.0900  296  24.0
# 1   7.07  6.421  4.9671  242  21.6
# 2   7.07  7.185  4.9671  242  34.7
# 3   2.18  6.998  6.0622  222  33.4
# 4   2.18  7.147  6.0622  222  36.2

# %%
x=df.iloc[:,:4]
x.head()
# Out:
#    INDUS     RM     DIS  TAX
# 0   2.31  6.575  4.0900  296
# 1   7.07  6.421  4.9671  242
# 2   7.07  7.185  4.9671  242
# 3   2.18  6.998  6.0622  222
# 4   2.18  7.147  6.0622  222

# %%
y=df.iloc[:,-1]
y.head()
# Out:
# 0    24.0
# 1    21.6
# 2    34.7
# 3    33.4
# 4    36.2
# Name: MEDV, dtype: float64

# %%
plt.scatter(df['RM'],df['MEDV'])
plt.show()

# %%
plt.scatter(df['INDUS'],df['MEDV'])
plt.show()

# %%
plt.scatter(df['TAX'],df['MEDV'])
plt.show()

# %%
plt.scatter(df['DIS'],df['MEDV'])
plt.show()

# %%
sns.pairplot(df)

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,train_size=0.67,random_state=2)

# %%
x_train
# Out:
#      INDUS     RM     DIS  TAX
# 419  18.10  6.824  1.7940  666
# 217  13.89  6.642  3.4211  276
# 106   8.56  5.836  2.2110  384
# 94   15.04  6.249  3.6150  270
# 280   3.33  7.820  4.6947  216
# ..     ...    ...     ...  ...
# 22    8.14  6.142  3.9769  307
# 72   10.81  6.065  5.2873  305
# 493   9.69  5.707  2.3817  391
# 15    8.14  5.834  4.4986  307
# 168  19.58  6.319  2.1000  403
#
# [339 rows x 4 columns]

# %%
x_test
# Out:
#      INDUS     RM     DIS  TAX
# 463  18.10  6.513  2.8016  666
# 152  19.58  5.012  1.6102  403
# 291   4.95  7.148  5.1167  245
# 183   2.46  6.563  2.8470  193
# 384  18.10  4.368  1.4395  666
# ..     ...    ...     ...  ...
# 29    8.14  6.674  4.2390  307
# 267   3.97  8.297  2.4216  264
# 142  19.58  5.403  1.3216  403
# 405  18.10  5.683  1.4254  666
# 342   1.89  6.540  6.2669  422
#
# [167 rows x 4 columns]

# %%
y_train
# Out:
# 419     8.4
# 217    28.7
# 106    19.5
# 94     20.6
# 280    45.4
#        ...
# 22     15.2
# 72     22.8
# 493    21.8
# 15     19.9
# 168    23.8
# Name: MEDV, Length: 339, dtype: float64

# %%
y_test
# Out:
# 463    20.2
# 152    15.3
# 291    37.3
# 183    32.5
# 384     8.8
#        ...
# 29     21.0
# 267    50.0
# 142    13.4
# 405     5.0
# 342    16.5
# Name: MEDV, Length: 167, dtype: float64

# %%
from sklearn.linear_model import LinearRegression

# %%
lr=LinearRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
a=lr.predict(x_test)

# %%
lr.coef_
# Out:
# array([-0.26154632,  7.05177822, -0.58429454, -0.01240213])

# %%
lr.intercept_
# Out:
# -11.59507837943261

# %%
from sklearn.metrics import mean_squared_error
lrr_mse=mean_squared_error(y_test,a)
lrr_mse
# Out:
# 31.913695302078402

# %%
import numpy as np
lrr_rmse=np.sqrt(lrr_mse)
lrr_rmse
# Out:
# 5.649220769458244

# %%
from sklearn.metrics import r2_score

# %%
r2_score(y_test,a)
# Out:
# 0.6411378526650199
