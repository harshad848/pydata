# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_excel('dataset/Saledata.xlsx')
df
# Out:
#     OrderDate   Region  Manager   SalesMan          Item   Units  Unit_price  \
# 0  2018-01-06     East   Martha  Alexander    Television   95.00    1198.000
# 1  2018-01-23  Central  Hermann     Shelli  Home Theater   50.00     500.000
# 2  2018-02-09  Central  Hermann       Luis    Television   36.00    1198.000
# 3  2018-02-26  Central  Timothy      David    Cell Phone   27.00     225.000
# 4  2018-03-15     West  Timothy    Stephen    Television   56.00    1198.000
# 5  2018-04-01     East   Martha  Alexander  Home Theater   60.00     500.000
# 6  2018-04-18  Central   Martha     Steven    Television   75.00    1198.000
# 7  2018-05-05  Central  Hermann       Luis    Television   90.00    1198.000
# 8  2018-05-22     West  Douglas    Michael    Television   32.00    1198.000
# 9  2018-06-08     East   Martha  Alexander  Home Theater   60.00     500.000
# 10 2018-06-25  Central  Hermann      Sigal    Television   90.00    1198.000
# ...

# %% [raw]
# 1. Write a Pandas program to create a Pivot table with multiple indexes from a given excel sheet (Salesdata.xlsx).

# %%
df1 =pd.pivot_table(df,index=['Manager','Region','OrderDate','SalesMan']).head()
df1
# Out:
#                                      Sale_amt  Unit_price  Units
# Manager Region  OrderDate  SalesMan
# Douglas Central 2018-09-01 John         250.0       125.0    2.0
#                 2018-12-12 John       80266.0      1198.0   67.0
#                 2019-02-01 John       43500.0       500.0   87.0
#         East    2018-07-29 Karen      40500.0       500.0   81.0
#                 2018-11-08 Karen       3375.0       225.0   15.0

# %% [raw]
# 2. Write a Pandas program to create a Pivot table and find the total sale amount region wise, manager wise.

# %%
dF1=pd.pivot_table(df,index=['Region','Manager'],values=('Sale_amt'),aggfunc='sum')
df1
# Out:
#                                      Sale_amt  Unit_price  Units
# Manager Region  OrderDate  SalesMan
# Douglas Central 2018-09-01 John         250.0       125.0    2.0
#                 2018-12-12 John       80266.0      1198.0   67.0
#                 2019-02-01 John       43500.0       500.0   87.0
#         East    2018-07-29 Karen      40500.0       500.0   81.0
#                 2018-11-08 Karen       3375.0       225.0   15.0

# %% [raw]
# 3. Write a Pandas program to create a Pivot table and find the total sale amount region wise, manager wise, sales man wise.

# %%
df1=pd.pivot_table(df,index=['Region','Manager','SalesMan'],values=('Sale_amt'),aggfunc='sum')
df1
# Out:
#                            Sale_amt
# Region  Manager SalesMan
# Central Douglas John       124016.0
#         Hermann Luis       206373.0
#                 Shelli      33698.0
#                 Sigal      125037.5
#         Martha  Steven     199690.0
#         Timothy David      140955.0
# East    Douglas Karen       48204.0
#         Martha  Alexander  236703.0
#                 Diana       36100.0
# West    Douglas Michael     66836.0
#         Timothy Stephen     88063.0

# %% [raw]
# 4. Write a Pandas program to create a Pivot table and find the item wise unit sold.

# %%
df1=pd.pivot_table(df,index='Item',values='Units',aggfunc=['sum'])
df1
# Out:
#                 sum
#               Units
# Item
# Cell Phone    278.0
# Desk           10.0
# Home Theater  722.0
# Television    716.0
# Video Games   395.0

# %% [raw]
# 5. Write a Pandas program to create a Pivot table and find the region wise total sale.

# %%
df1=pd.pivot_table(df,index='Region',values='Units')
df1
# Out:
#              Units
# Region
# Central  49.958333
# East     53.153846
# West     38.500000

# %% [raw]
# 6. Write a Pandas program to create a Pivot table and find the region wise, item wise unit sold

# %%
df1=pd.pivot_table(df,index=['Region','Item'],values='Units')
df1
# Out:
#                           Units
# Region  Item
# Central Cell Phone    27.000000
#         Desk           3.500000
#         Home Theater  53.000000
#         Television    55.333333
#         Video Games   60.750000
# East    Cell Phone    58.333333
#         Home Theater  46.800000
#         Television    65.000000
#         Video Games   50.666667
# West    Cell Phone    76.000000
#         Desk           3.000000
#         Home Theater  32.000000
#         Television    44.000000

# %% [raw]
# 7. Write a Pandas program to create a Pivot table and count the manager wise sale and mean value of sale amount.

# %%
df1=pd.pivot_table(df,index='Manager',values='Sale_amt',aggfunc=['count'])
df1
# Out:
#            count
#         Sale_amt
# Manager
# Douglas        8
# Hermann       12
# Martha        14
# Timothy        9

# %% [raw]
# 8. Write a Pandas program to create a Pivot table and find manager wise, salesman wise total sale and also display the sum of all sale amount at the bottom.

# %%
df1=pd.pivot_table(df,index=['Manager','SalesMan'],values='Units',aggfunc=['sum'])
df1
# Out:
#                      sum
#                    Units
# Manager SalesMan
# Douglas John       156.0
#         Karen      170.0
#         Michael     89.0
# Hermann Luis       281.0
#         Shelli     193.0
#         Sigal      173.0
# Martha  Alexander  396.0
#         Diana      125.0
#         Steven     183.0
# Timothy David      213.0
#         Stephen    142.0

# %% [raw]
# 9. Write a Pandas program to create a Pivot table and find the total sale amount region wise, manager wise, sales man wise where Manager = "Douglas".

# %%
df1=pd.pivot_table(df,index=['Region','Manager','SalesMan'],columns='Sale_amt').head()
print(douglas.query('Manager == ["Douglas"]'))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [27], in <cell line: 2>()
#       1 df1=pd.pivot_table(df,index=['Region','Manager','SalesMan'],columns='Sale_amt').head()
# ----> 2 print(douglas.query('Manager == ["Douglas"]'))
#
# NameError: name 'douglas' is not defined

# %% [raw]
# 10. Write a Pandas program to create a Pivot table and find the region wise Television and Home Theater sold.

# %%
Television =pd.pivot_table(df,index=['Region','Item'],values='Units')
print(Television.query('Item == ["Television",Home Theater"]'))
# Out:
# Traceback (most recent call last):
#
#   File ~\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3369 in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   Input In [28] in <cell line: 2>
#     print(Television.query('Item == ["Television",Home Theater"]'))
#
#   File ~\anaconda3\lib\site-packages\pandas\core\frame.py:4111 in query
#     res = self.eval(expr, **kwargs)
#
#   File ~\anaconda3\lib\site-packages\pandas\core\frame.py:4240 in eval
#     return _eval(expr, inplace=inplace, **kwargs)
#
#   File ~\anaconda3\lib\site-packages\pandas\core\computation\eval.py:350 in eval
#     parsed_expr = Expr(expr, engine=engine, parser=parser, env=env)
#
#   File ~\anaconda3\lib\site-packages\pandas\core\computation\expr.py:811 in __init__
#     self.terms = self.parse()
#
#   File ~\anaconda3\lib\site-packages\pandas\core\computation\expr.py:830 in parse
#     return self._visitor.visit(self.expr)
#
# ...

# %% [raw]
# 11. Write a Pandas program to create a Pivot table and find the maximum sale value of the items.

# %% [raw]
# 12. Write a Pandas program to create a Pivot table and find the minimum sale value of the items.

# %% [raw]
# 13.Write a Pandas program to create a Pivot table and find the maximum and minimum sale value of the items.
